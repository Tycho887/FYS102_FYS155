# %% [markdown]
# \newpage
#
# **Oppgave 19.17**
#
# ![Image Alt Text](../oppgave_bilder/Oppgave19_17.png)
#
# Konstanter:
#
# - $d=0.96\text{ m}$
# - $q = 2.0\times 10^{-6}\text{ C}$
#
# Elektrisk potensial er gitt ved
#
# $V_P = \frac{1}{4\pi\epsilon_0}\sum_{i=1}^{N}{\frac{q_i}{r}}$
#
# Setter inn verdier
#
# $$V_P = \frac{1}{4\pi\epsilon_0}\sum_{i=1}^{N}{\frac{q_i}{r}} = \frac{1}{4\pi\epsilon_0}\left(\frac{-q}{d} + \frac{-q}{d} + \frac{q}{d} + \frac{q}{2d}\right)$$
# $$V_P = \frac{1}{4\pi\epsilon_0}
# \left(
# \frac{-2.0\mu\text{C}}{0.96\text{ m}} +
# \frac{-2.0\mu\text{C}}{0.96\text{ m}} +
# \frac{2.0\mu\text{C}}{0.96\text{ m}} +
# \frac{2.0\mu\text{C}}{1.92\text{ m}}
# \right)$$
#
# $$V_P = -9.4\text{kV}$$
#
# \newpage
#
# **Oppgave 19.26**
#
# Konstanter:
#
# - $d=0.40\text{ m}$
# - $q = 2.0\times 10^{-6}\text{ C}$
#
# For å finne den totale potensielle energien i systemet

# %%
import matplotlib.pyplot as plt

d = 0.4
q = 2.0e-6

plt.scatter(d, 0,color='red',label='punktladninger')
plt.scatter(2*d,0,color='red')
plt.scatter(3*d,0,color='red')
plt.scatter(4*d,0,color='red')

plt.legend(loc='upper right')
plt.grid()

# we want to drop the axis values

plt.savefig('../oppgave_bilder/Oppgave19_26.png')
plt.show()
