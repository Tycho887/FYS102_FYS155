# %% [markdown]
# # Oppgave 5
#
# <h3>Del A: Visualiser en isoterm kompresjon</h3>
#
# Her benyttes termoPy biblioteket for å finne ukjente mengder til en ideell gass, og deretter plotting av en isoterm process

# %%
import termoPy as TP
import matplotlib.pyplot as plt
import numpy as np

atm = 101300; L = 0.001

initial_volume = TP.IdealGas(n=3,P1=1*atm,T1=273).V1
final_volume = initial_volume*0.50

isoterm_prosess = TP.Isothermal(n=3,T=273,P1=1*atm)
isoterm_prosess.generate_data_from_dV(V2=final_volume)

# %% [markdown]
# <h3>Del B: Visualiser en adiabatisk kompresjon</h3>
#
# Vi benytter igjen termoPy biblioteket for å plotte den adiabatiske kompresjonen.

# %%
adiabatisk_prosess = TP.Adiabatic(n=3,gamma=7/5,T1=273,P1=1*atm)
adiabatisk_prosess.generate_data_from_dV(V2=final_volume)

def plot_processes(A,B):

    plot_title = A.title + " og " + B.title

    plt.title(plot_title)
    plt.xlabel("Volum [m^3]")
    plt.ylabel("Trykk [Pa]")
    plt.plot(A.volume,A.pressure,label=A.title)
    plt.plot(B.volume,B.pressure,label=B.title)
    plt.legend()
    plt.grid()
    plt.show()

plot_processes(isoterm_prosess,adiabatisk_prosess)

# %%
import termoPy as TP

mol = TP.IdealGas(P1=1*atm,V1=50*L,T1=273).n

# Normaltilstand

P  = 1.0 * atm
T = 273
V1 = 50*L
V2 = 10*L
k = 10000

isoterm_prosess    = TP.Isothermal(n=mol, T = T, V1 = V1, P1 = P)
adiabatisk_prosess = TP.Adiabatic(n=mol, T1 = T, V1 = V1, P1 = P,gamma = 7/5)

isoterm_prosess.generate_data_from_dV(V2,steps=k)
adiabatisk_prosess.generate_data_from_dV(V2,steps=k)

def integrate(A):
    dV = (V2-V1)/k
    return dV*np.sum(A.pressure)

print(integrate(isoterm_prosess))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Jobb og Skole\OneDrive - Norwegian University of Life Sciences\Desktop\Fysikk\FYS102_FYS155\FYS155\kollokvie_termo_oppgave5.ipynb Cell 5 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/Jobb%20og%20Skole/OneDrive%20-%20Norwegian%20University%20of%20Life%20Sciences/Desktop/Fysikk/FYS102_FYS155/FYS155/kollokvie_termo_oppgave5.ipynb#W4sZmlsZQ%3D%3D?line=12'>13</a> isoterm_prosess    = TP.Isothermal(n=mol, T = T, V1 = V1, P1 = P)
#      <a href='vscode-notebook-cell:/c%3A/Users/Jobb%20og%20Skole/OneDrive%20-%20Norwegian%20University%20of%20Life%20Sciences/Desktop/Fysikk/FYS102_FYS155/FYS155/kollokvie_termo_oppgave5.ipynb#W4sZmlsZQ%3D%3D?line=13'>14</a> adiabatisk_prosess = TP.Adiabatic(n=mol, T1 = T, V1 = V1, P1 = P,gamma = 7/5)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Jobb%20og%20Skole/OneDrive%20-%20Norwegian%20University%20of%20Life%20Sciences/Desktop/Fysikk/FYS102_FYS155/FYS155/kollokvie_termo_oppgave5.ipynb#W4sZmlsZQ%3D%3D?line=15'>16</a> isoterm_prosess.generate_graph_from_dV(V2,steps=k)
#      <a href='vscode-notebook-cell:/c%3A/Users/Jobb%20og%20Skole/OneDrive%20-%20Norwegian%20University%20of%20Life%20Sciences/Desktop/Fysikk/FYS102_FYS155/FYS155/kollokvie_termo_oppgave5.ipynb#W4sZmlsZQ%3D%3D?line=16'>17</a> adiabatisk_prosess.generate_graph_from_dV(V2,steps=k)
#      <a href='vscode-notebook-cell:/c%3A/Users/Jobb%20og%20Skole/OneDrive%20-%20Norwegian%20University%20of%20Life%20Sciences/Desktop/Fysikk/FYS102_FYS155/FYS155/kollokvie_termo_oppgave5.ipynb#W4sZmlsZQ%3D%3D?line=18'>19</a> def integrate(A):
#
# TypeError: Isothermal.generate_graph_from_dV() got an unexpected keyword argument 'steps'
